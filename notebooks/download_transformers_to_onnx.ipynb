# %% [markdown]
# ## Converting HuggingFace Models to ONNX

# %%
import os
from pathlib import Path
from optimum.exporters.onnx import main_export

# %%
from transformers import WhisperConfig
from optimum.exporters.onnx import main_export
from optimum.exporters.onnx.model_configs import WhisperOnnxConfig

# Specify the model name or path
model_id = "openai/whisper-large-v3"

# Load the Whisper config from Hugging Face
whisper_config = WhisperConfig.from_pretrained(model_id, from_flax=True)

# Define the ONNX export configuration using WhisperOnnxConfig
onnx_config = WhisperOnnxConfig(whisper_config)

# Set the export directory and filename for the ONNX model
onnx_model_path = "onnx/whisper-large-v3.onnx"

# Export the model to ONNX using Optimum
main_export(model_id,   # Pass the correct argument here
            config=onnx_config, 
            output=onnx_model_path,
            task="automatic-speech-recognition")
# Out:
# Moving the following attributes in the config to the generation config: {'max_length': 448, 'begin_suppress_tokens': [220, 50257]}. You are seeing this warning because you've set generation parameters in the model config, as opposed to in the generation config.
# c:\Users\joel\Desktop\AI-ML-Engineering-MonoRepo\.venv\Lib\site-packages\transformers\models\whisper\modeling_whisper.py:1019: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if input_features.shape[-1] != expected_seq_length:
# c:\Users\joel\Desktop\AI-ML-Engineering-MonoRepo\.venv\Lib\site-packages\transformers\models\whisper\modeling_whisper.py:339: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if attn_output.size() != (bsz, self.num_heads, tgt_len, self.head_dim):
# c:\Users\joel\Desktop\AI-ML-Engineering-MonoRepo\.venv\Lib\site-packages\transformers\models\whisper\modeling_whisper.py:1484: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if sequence_length != 1:
# Found different candidate ONNX initializers (likely duplicate) for the tied weights:
# 	model.decoder.embed_tokens.weight: {'model.decoder.embed_tokens.weight'}
# 	proj_out.weight: {'onnx::MatMul_8506'}
# 		-[x] values not close enough, max diff: 0.015755653381347656 (atol: 0.001)
# The ONNX export succeeded with the warning: The maximum absolute difference between the output of the reference model and the ONNX exported model is not within the set tolerance 0.001:
# - last_hidden_state: max diff = 0.015755653381347656.
#  The exported model was saved at: onnx/whisper-large-v3.onnx

# %%
model_id = "openai/whisper-large-v3"

print("Exporting model as ONNX")

main_export(
    model_id,
    output="onnx/out",
    task="automatic-speech-recognition"
)

#config = WhisperConfig.from_pretrained(model_id)
#onnx_config = WhisperOnnxConfig(config, task="automatic-speech-recognition")
# Out:
# Exporting model as ONNX
# Moving the following attributes in the config to the generation config: {'max_length': 448, 'begin_suppress_tokens': [220, 50257]}. You are seeing this warning because you've set generation parameters in the model config, as opposed to in the generation config.
# c:\Users\joel\Desktop\AI-ML-Engineering-MonoRepo\.venv\Lib\site-packages\transformers\models\whisper\modeling_whisper.py:1019: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if input_features.shape[-1] != expected_seq_length:
# c:\Users\joel\Desktop\AI-ML-Engineering-MonoRepo\.venv\Lib\site-packages\transformers\models\whisper\modeling_whisper.py:339: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if attn_output.size() != (bsz, self.num_heads, tgt_len, self.head_dim):
# c:\Users\joel\Desktop\AI-ML-Engineering-MonoRepo\.venv\Lib\site-packages\transformers\models\whisper\modeling_whisper.py:1484: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if sequence_length != 1:
# Found different candidate ONNX initializers (likely duplicate) for the tied weights:
# 	model.decoder.embed_tokens.weight: {'model.decoder.embed_tokens.weight'}
# 	proj_out.weight: {'onnx::MatMul_8506'}
# 		-[x] values not close enough, max diff: 0.021198749542236328 (atol: 0.001)
# The ONNX export succeeded with the warning: The maximum absolute difference between the output of the reference model and the ONNX exported model is not within the set tolerance 0.001:
# - last_hidden_state: max diff = 0.021198749542236328.
#  The exported model was saved at: onnx/out

# %% [markdown]
# ## Quantize the model

# %%
import onnx
model = onnx.load("onnx/out/decoder_model.onnx")
for node in model.graph.node:
    print(node.name, node.op_type)
# Out:
# /model/decoder/Shape Shape
# /model/decoder/Constant Constant
# /model/decoder/Gather Gather
# /model/decoder/Constant_1 Constant
# /model/decoder/Shape_1 Shape
# /model/decoder/Constant_2 Constant
# /model/decoder/Gather_1 Gather
# /model/decoder/Constant_3 Constant
# Constant_1638 Constant
# /model/decoder/Unsqueeze Unsqueeze
# /model/decoder/Concat Concat
# /model/decoder/Reshape Reshape
# /model/decoder/embed_tokens/Gather Gather
# /model/decoder/Constant_4 Constant
# /model/decoder/Cast Cast
# /model/decoder/Constant_5 Constant
# /model/decoder/Range Range
# /model/decoder/Constant_6 Constant
# /model/decoder/Unsqueeze_1 Unsqueeze
# Constant_1649 Constant
# /model/decoder/Unsqueeze_2 Unsqueeze
# /model/decoder/Constant_7 Constant
# /model/decoder/Concat_1 Concat
# Constant_1653 Constant
# /model/decoder/Unsqueeze_3 Unsqueeze
# /model/decoder/Constant_8 Constant
# /model/decoder/Concat_2 Concat
# /model/decoder/Shape_2 Shape
# /model/decoder/ConstantOfShape ConstantOfShape
# /model/decoder/Expand Expand
# /model/decoder/Tile Tile
# /model/decoder/embed_positions/Gather Gather
# /model/decoder/Cast_1 Cast
# /model/decoder/Add Add
# /model/decoder/Shape_3 Shape
# /model/decoder/Constant_9 Constant
# /model/decoder/Gather_2 Gather
# /model/decoder/Constant_10 Constant
# /model/decoder/Add_1 Add
# /model/decoder/Shape_4 Shape
# /model/decoder/Constant_11 Constant
# /model/decoder/Gather_3 Gather
# Constant_1672 Constant
# /model/decoder/Unsqueeze_4 Unsqueeze
# Constant_1674 Constant
# /model/decoder/Unsqueeze_5 Unsqueeze
# /model/decoder/Concat_3 Concat
# /model/decoder/ConstantOfShape_1 ConstantOfShape
# /model/decoder/Trilu Trilu
# /model/decoder/Cast_2 Cast
# /model/decoder/Constant_12 Constant
# /model/decoder/Constant_13 Constant
# /model/decoder/Range_1 Range
# /model/decoder/Constant_14 Constant
# /model/decoder/Reshape_1 Reshape
# /model/decoder/Greater Greater
# Cast_1686 Cast
# /model/decoder/Mul Mul
# /model/decoder/Constant_15 Constant
# /model/decoder/Unsqueeze_6 Unsqueeze
# /model/decoder/Constant_16 Constant
# /model/decoder/Unsqueeze_7 Unsqueeze
# /model/decoder/Constant_17 Constant
# /model/decoder/Unsqueeze_8 Unsqueeze
# /model/decoder/Constant_18 Constant
# /model/decoder/Constant_19 Constant
# /model/decoder/Constant_20 Constant
# /model/decoder/Concat_4 Concat
# /model/decoder/Constant_21 Constant
# /model/decoder/Reshape_2 Reshape
# /model/decoder/Shape_5 Shape
# /model/decoder/ConstantOfShape_2 ConstantOfShape
# /model/decoder/Constant_22 Constant
# /model/decoder/Mul_1 Mul
# /model/decoder/Equal Equal
# /model/decoder/Where Where
# /model/decoder/Expand_1 Expand
# /model/decoder/layers.0/self_attn_layer_norm/ReduceMean ReduceMean
# /model/decoder/layers.0/self_attn_layer_norm/Sub Sub
# /model/decoder/layers.0/self_attn_layer_norm/Constant Constant
# /model/decoder/layers.0/self_attn_layer_norm/Pow Pow
# /model/decoder/layers.0/self_attn_layer_norm/ReduceMean_1 ReduceMean
# /model/decoder/layers.0/self_attn_layer_norm/Constant_1 Constant
# /model/decoder/layers.0/self_attn_layer_norm/Add Add
# /model/decoder/layers.0/self_attn_layer_norm/Sqrt Sqrt
# /model/decoder/layers.0/self_attn_layer_norm/Div Div
# /model/decoder/layers.0/self_attn_layer_norm/Mul Mul
# /model/decoder/layers.0/self_attn_layer_norm/Add_1 Add
# /model/decoder/layers.0/self_attn/Shape Shape
# /model/decoder/layers.0/self_attn/Constant Constant
# /model/decoder/layers.0/self_attn/Gather Gather
# /model/decoder/layers.0/self_attn/Shape_1 Shape
# /model/decoder/layers.0/self_attn/Constant_1 Constant
# /model/decoder/layers.0/self_attn/Gather_1 Gather
# /model/decoder/layers.0/self_attn/q_proj/MatMul MatMul
# /model/decoder/layers.0/self_attn/q_proj/Add Add
# /model/decoder/layers.0/self_attn/Constant_2 Constant
# /model/decoder/layers.0/self_attn/Mul Mul
# Constant_1728 Constant
# /model/decoder/layers.0/self_attn/Unsqueeze Unsqueeze
# Constant_1730 Constant
# /model/decoder/layers.0/self_attn/Unsqueeze_1 Unsqueeze
# /model/decoder/layers.0/self_attn/Constant_3 Constant
# /model/decoder/layers.0/self_attn/Constant_4 Constant
# /model/decoder/layers.0/self_attn/Concat Concat
# /model/decoder/layers.0/self_attn/Reshape Reshape
# /model/decoder/layers.0/self_attn/Transpose Transpose
# /model/decoder/layers.0/self_attn/k_proj/MatMul MatMul
# Constant_1738 Constant
# /model/decoder/layers.0/self_attn/Unsqueeze_2 Unsqueeze
# /model/decoder/layers.0/self_attn/Constant_5 Constant
# /model/decoder/layers.0/self_attn/Constant_6 Constant
# /model/decoder/layers.0/self_attn/Constant_7 Constant
# /model/decoder/layers.0/self_attn/Concat_1 Concat
# Constant_1744 Constant
# /model/decoder/layers.0/self_attn/Unsqueeze_3 Unsqueeze
# /model/decoder/layers.0/self_attn/Constant_8 Constant
# /model/decoder/layers.0/self_attn/Constant_9 Constant
# /model/decoder/layers.0/self_attn/Constant_10 Constant
# /model/decoder/layers.0/self_attn/Concat_2 Concat
# /model/decoder/layers.0/self_attn/Reshape_1 Reshape
# /model/decoder/layers.0/self_attn/Transpose_1 Transpose
# /model/decoder/layers.0/self_attn/v_proj/MatMul MatMul
# /model/decoder/layers.0/self_attn/v_proj/Add Add
# /model/decoder/layers.0/self_attn/Reshape_2 Reshape
# /model/decoder/layers.0/self_attn/Transpose_2 Transpose
# /model/decoder/layers.0/self_attn/Transpose_3 Transpose
# /model/decoder/layers.0/self_attn/MatMul MatMul
# /model/decoder/layers.0/self_attn/Shape_2 Shape
# /model/decoder/layers.0/self_attn/Constant_11 Constant
# /model/decoder/layers.0/self_attn/Gather_2 Gather
# /model/decoder/layers.0/self_attn/Constant_12 Constant
# /model/decoder/layers.0/self_attn/Constant_13 Constant
# /model/decoder/layers.0/self_attn/Constant_14 Constant
# /model/decoder/layers.0/self_attn/Unsqueeze_4 Unsqueeze
# /model/decoder/layers.0/self_attn/Constant_15 Constant
# /model/decoder/layers.0/self_attn/Slice Slice
# /model/decoder/layers.0/self_attn/Add Add
# /model/decoder/layers.0/self_attn/Softmax Softmax
# /model/decoder/layers.0/self_attn/MatMul_1 MatMul
# /model/decoder/layers.0/self_attn/Transpose_4 Transpose
# Constant_1771 Constant
# /model/decoder/layers.0/self_attn/Unsqueeze_5 Unsqueeze
# Constant_1773 Constant
# /model/decoder/layers.0/self_attn/Unsqueeze_6 Unsqueeze
# /model/decoder/layers.0/self_attn/Constant_16 Constant
# /model/decoder/layers.0/self_attn/Concat_3 Concat
# /model/decoder/layers.0/self_attn/Reshape_3 Reshape
# /model/decoder/layers.0/self_attn/out_proj/MatMul MatMul
# /model/decoder/layers.0/self_attn/out_proj/Add Add
# /model/decoder/layers.0/Add Add
# /model/decoder/layers.0/encoder_attn_layer_norm/ReduceMean ReduceMean
# /model/decoder/layers.0/encoder_attn_layer_norm/Sub Sub
# /model/decoder/layers.0/encoder_attn_layer_norm/Constant Constant
# /model/decoder/layers.0/encoder_attn_layer_norm/Pow Pow
# /model/decoder/layers.0/encoder_attn_layer_norm/ReduceMean_1 ReduceMean
# /model/decoder/layers.0/encoder_attn_layer_norm/Constant_1 Constant
# /model/decoder/layers.0/encoder_attn_layer_norm/Add Add
# /model/decoder/layers.0/encoder_attn_layer_norm/Sqrt Sqrt
# /model/decoder/layers.0/encoder_attn_layer_norm/Div Div
# /model/decoder/layers.0/encoder_attn_layer_norm/Mul Mul
# /model/decoder/layers.0/encoder_attn_layer_norm/Add_1 Add
# /model/decoder/layers.0/encoder_attn/Shape Shape
# /model/decoder/layers.0/encoder_attn/Constant Constant
# /model/decoder/layers.0/encoder_attn/Gather Gather
# /model/decoder/layers.0/encoder_attn/Shape_1 Shape
# /model/decoder/layers.0/encoder_attn/Constant_1 Constant
# /model/decoder/layers.0/encoder_attn/Gather_1 Gather
# /model/decoder/layers.0/encoder_attn/q_proj/MatMul MatMul
# /model/decoder/layers.0/encoder_attn/q_proj/Add Add
# /model/decoder/layers.0/encoder_attn/Constant_2 Constant
# /model/decoder/layers.0/encoder_attn/Mul Mul
# Constant_1802 Constant
# /model/decoder/layers.0/encoder_attn/Unsqueeze Unsqueeze
# Constant_1804 Constant
# /model/decoder/layers.0/encoder_attn/Unsqueeze_1 Unsqueeze
# /model/decoder/layers.0/encoder_attn/Constant_3 Constant
# /model/decoder/layers.0/encoder_attn/Constant_4 Constant
# /model/decoder/layers.0/encoder_attn/Concat Concat
# /model/decoder/layers.0/encoder_attn/Reshape Reshape
# /model/decoder/layers.0/encoder_attn/Transpose Transpose
# /model/decoder/layers.0/encoder_attn/k_proj/MatMul MatMul
# Constant_1812 Constant
# /model/decoder/layers.0/encoder_attn/Unsqueeze_2 Unsqueeze
# /model/decoder/layers.0/encoder_attn/Constant_5 Constant
# /model/decoder/layers.0/encoder_attn/Constant_6 Constant
# /model/decoder/layers.0/encoder_attn/Constant_7 Constant
# /model/decoder/layers.0/encoder_attn/Concat_1 Concat
# Constant_1818 Constant
# /model/decoder/layers.0/encoder_attn/Unsqueeze_3 Unsqueeze
# /model/decoder/layers.0/encoder_attn/Constant_8 Constant
# /model/decoder/layers.0/encoder_attn/Constant_9 Constant
# /model/decoder/layers.0/encoder_attn/Constant_10 Constant
# /model/decoder/layers.0/encoder_attn/Concat_2 Concat
# /model/decoder/layers.0/encoder_attn/Reshape_1 Reshape
# /model/decoder/layers.0/encoder_attn/v_proj/MatMul MatMul
# /model/decoder/layers.0/encoder_attn/v_proj/Add Add
# /model/decoder/layers.0/encoder_attn/Reshape_2 Reshape
# /model/decoder/layers.0/encoder_attn/Transpose_1 Transpose
# /model/decoder/layers.0/encoder_attn/Transpose_2 Transpose
# /model/decoder/layers.0/encoder_attn/MatMul MatMul
# /model/decoder/layers.0/encoder_attn/Softmax Softmax
# /model/decoder/layers.0/encoder_attn/MatMul_1 MatMul
# /model/decoder/layers.0/encoder_attn/Transpose_3 Transpose
# Constant_1834 Constant
# /model/decoder/layers.0/encoder_attn/Unsqueeze_4 Unsqueeze
# Constant_1836 Constant
# /model/decoder/layers.0/encoder_attn/Unsqueeze_5 Unsqueeze
# /model/decoder/layers.0/encoder_attn/Constant_11 Constant
# /model/decoder/layers.0/encoder_attn/Concat_3 Concat
# /model/decoder/layers.0/encoder_attn/Reshape_3 Reshape
# /model/decoder/layers.0/encoder_attn/out_proj/MatMul MatMul
# /model/decoder/layers.0/encoder_attn/out_proj/Add Add
# /model/decoder/layers.0/Add_1 Add
# /model/decoder/layers.0/final_layer_norm/ReduceMean ReduceMean
# /model/decoder/layers.0/final_layer_norm/Sub Sub
# /model/decoder/layers.0/final_layer_norm/Constant Constant
# /model/decoder/layers.0/final_layer_norm/Pow Pow
# /model/decoder/layers.0/final_layer_norm/ReduceMean_1 ReduceMean
# /model/decoder/layers.0/final_layer_norm/Constant_1 Constant
# /model/decoder/layers.0/final_layer_norm/Add Add
# /model/decoder/layers.0/final_layer_norm/Sqrt Sqrt
# /model/decoder/layers.0/final_layer_norm/Div Div
# /model/decoder/layers.0/final_layer_norm/Mul Mul
# /model/decoder/layers.0/final_layer_norm/Add_1 Add
# /model/decoder/layers.0/fc1/MatMul MatMul
# /model/decoder/layers.0/fc1/Add Add
# /model/decoder/layers.0/activation_fn/Constant Constant
# /model/decoder/layers.0/activation_fn/Div Div
# /model/decoder/layers.0/activation_fn/Erf Erf
# /model/decoder/layers.0/activation_fn/Constant_1 Constant
# /model/decoder/layers.0/activation_fn/Add Add
# /model/decoder/layers.0/activation_fn/Mul Mul
# /model/decoder/layers.0/activation_fn/Constant_2 Constant
# /model/decoder/layers.0/activation_fn/Mul_1 Mul
# /model/decoder/layers.0/fc2/MatMul MatMul
# /model/decoder/layers.0/fc2/Add Add
# /model/decoder/layers.0/Add_2 Add
# /model/decoder/layers.1/self_attn_layer_norm/ReduceMean ReduceMean
# /model/decoder/layers.1/self_attn_layer_norm/Sub Sub
# /model/decoder/layers.1/self_attn_layer_norm/Constant Constant
# /model/decoder/layers.1/self_attn_layer_norm/Pow Pow
# /model/decoder/layers.1/self_attn_layer_norm/ReduceMean_1 ReduceMean
# /model/decoder/layers.1/self_attn_layer_norm/Constant_1 Constant
# /model/decoder/layers.1/self_attn_layer_norm/Add Add
# /model/decoder/layers.1/self_attn_layer_norm/Sqrt Sqrt
# /model/decoder/layers.1/self_attn_layer_norm/Div Div
# /model/decoder/layers.1/self_attn_layer_norm/Mul Mul
# /model/decoder/layers.1/self_attn_layer_norm/Add_1 Add
# /model/decoder/layers.1/self_attn/Shape Shape
# /model/decoder/layers.1/self_attn/Constant Constant
# /model/decoder/layers.1/self_attn/Gather Gather
# /model/decoder/layers.1/self_attn/Shape_1 Shape
# /model/decoder/layers.1/self_attn/Constant_1 Constant
# /model/decoder/layers.1/self_attn/Gather_1 Gather
# /model/decoder/layers.1/self_attn/q_proj/MatMul MatMul
# /model/decoder/layers.1/self_attn/q_proj/Add Add
# /model/decoder/layers.1/self_attn/Constant_2 Constant
# /model/decoder/layers.1/self_attn/Mul Mul
# Constant_1889 Constant
# /model/decoder/layers.1/self_attn/Unsqueeze Unsqueeze
# Constant_1891 Constant
# /model/decoder/layers.1/self_attn/Unsqueeze_1 Unsqueeze
# /model/decoder/layers.1/self_attn/Constant_3 Constant
# /model/decoder/layers.1/self_attn/Constant_4 Constant
# /model/decoder/layers.1/self_attn/Concat Concat
# /model/decoder/layers.1/self_attn/Reshape Reshape
# /model/decoder/layers.1/self_attn/Transpose Transpose
# /model/decoder/layers.1/self_attn/k_proj/MatMul MatMul
# Constant_1899 Constant
# /model/decoder/layers.1/self_attn/Unsqueeze_2 Unsqueeze
# /model/decoder/layers.1/self_attn/Constant_5 Constant
# /model/decoder/layers.1/self_attn/Constant_6 Constant
# /model/decoder/layers.1/self_attn/Constant_7 Constant
# /model/decoder/layers.1/self_attn/Concat_1 Concat
# Constant_1905 Constant
# /model/decoder/layers.1/self_attn/Unsqueeze_3 Unsqueeze
# /model/decoder/layers.1/self_attn/Constant_8 Constant
# /model/decoder/layers.1/self_attn/Constant_9 Constant
# /model/decoder/layers.1/self_attn/Constant_10 Constant
# /model/decoder/layers.1/self_attn/Concat_2 Concat
# /model/decoder/layers.1/self_attn/Reshape_1 Reshape
# /model/decoder/layers.1/self_attn/Transpose_1 Transpose
# /model/decoder/layers.1/self_attn/v_proj/MatMul MatMul
# /model/decoder/layers.1/self_attn/v_proj/Add Add
# /model/decoder/layers.1/self_attn/Reshape_2 Reshape
# /model/decoder/layers.1/self_attn/Transpose_2 Transpose
# /model/decoder/layers.1/self_attn/Transpose_3 Transpose
# /model/decoder/layers.1/self_attn/MatMul MatMul
# /model/decoder/layers.1/self_attn/Shape_2 Shape
# /model/decoder/layers.1/self_attn/Constant_11 Constant
# /model/decoder/layers.1/self_attn/Gather_2 Gather
# /model/decoder/layers.1/self_attn/Constant_12 Constant
# /model/decoder/layers.1/self_attn/Constant_13 Constant
# /model/decoder/layers.1/self_attn/Constant_14 Constant
# /model/decoder/layers.1/self_attn/Unsqueeze_4 Unsqueeze
# /model/decoder/layers.1/self_attn/Constant_15 Constant
# /model/decoder/layers.1/self_attn/Slice Slice
# /model/decoder/layers.1/self_attn/Add Add
# /model/decoder/layers.1/self_attn/Softmax Softmax
# /model/decoder/layers.1/self_attn/MatMul_1 MatMul
# /model/decoder/layers.1/self_attn/Transpose_4 Transpose
# Constant_1932 Constant
# /model/decoder/layers.1/self_attn/Unsqueeze_5 Unsqueeze
# Constant_1934 Constant
# /model/decoder/layers.1/self_attn/Unsqueeze_6 Unsqueeze
# /model/decoder/layers.1/self_attn/Constant_16 Constant
# /model/decoder/layers.1/self_attn/Concat_3 Concat
# /model/decoder/layers.1/self_attn/Reshape_3 Reshape
# /model/decoder/layers.1/self_attn/out_proj/MatMul MatMul
# /model/decoder/layers.1/self_attn/out_proj/Add Add
# /model/decoder/layers.1/Add Add
# /model/decoder/layers.1/encoder_attn_layer_norm/ReduceMean ReduceMean
# /model/decoder/layers.1/encoder_attn_layer_norm/Sub Sub
# /model/decoder/layers.1/encoder_attn_layer_norm/Constant Constant
# /model/decoder/layers.1/encoder_attn_layer_norm/Pow Pow
# /model/decoder/layers.1/encoder_attn_layer_norm/ReduceMean_1 ReduceMean
# /model/decoder/layers.1/encoder_attn_layer_norm/Constant_1 Constant
# /model/decoder/layers.1/encoder_attn_layer_norm/Add Add
# /model/decoder/layers.1/encoder_attn_layer_norm/Sqrt Sqrt
# /model/decoder/layers.1/encoder_attn_layer_norm/Div Div
# /model/decoder/layers.1/encoder_attn_layer_norm/Mul Mul
# /model/decoder/layers.1/encoder_attn_layer_norm/Add_1 Add
# /model/decoder/layers.1/encoder_attn/Shape Shape
# /model/decoder/layers.1/encoder_attn/Constant Constant
# /model/decoder/layers.1/encoder_attn/Gather Gather
# /model/decoder/layers.1/encoder_attn/Shape_1 Shape
# /model/decoder/layers.1/encoder_attn/Constant_1 Constant
# /model/decoder/layers.1/encoder_attn/Gather_1 Gather
# /model/decoder/layers.1/encoder_attn/q_proj/MatMul MatMul
# /model/decoder/layers.1/encoder_attn/q_proj/Add Add
# /model/decoder/layers.1/encoder_attn/Constant_2 Constant
# /model/decoder/layers.1/encoder_attn/Mul Mul
# Constant_1963 Constant
# /model/decoder/layers.1/encoder_attn/Unsqueeze Unsqueeze
# Constant_1965 Constant
# /model/decoder/layers.1/encoder_attn/Unsqueeze_1 Unsqueeze
# /model/decoder/layers.1/encoder_attn/Constant_3 Constant
# /model/decoder/layers.1/encoder_attn/Constant_4 Constant
# /model/decoder/layers.1/encoder_attn/Concat Concat
# /model/decoder/layers.1/encoder_attn/Reshape Reshape
# /model/decoder/layers.1/encoder_attn/Transpose Transpose
# /model/decoder/layers.1/encoder_attn/k_proj/MatMul MatMul
# Constant_1973 Constant
# /model/decoder/layers.1/encoder_attn/Unsqueeze_2 Unsqueeze
# /model/decoder/layers.1/encoder_attn/Constant_5 Constant
# /model/decoder/layers.1/encoder_attn/Constant_6 Constant
# /model/decoder/layers.1/encoder_attn/Constant_7 Constant
# /model/decoder/layers.1/encoder_attn/Concat_1 Concat
# Constant_1979 Constant
# /model/decoder/layers.1/encoder_attn/Unsqueeze_3 Unsqueeze
# /model/decoder/layers.1/encoder_attn/Constant_8 Constant
# /model/decoder/layers.1/encoder_attn/Constant_9 Constant
# /model/decoder/layers.1/encoder_attn/Constant_10 Constant
# /model/decoder/layers.1/encoder_attn/Concat_2 Concat
# /model/decoder/layers.1/encoder_attn/Reshape_1 Reshape
# /model/decoder/layers.1/encoder_attn/v_proj/MatMul MatMul
# /model/decoder/layers.1/encoder_attn/v_proj/Add Add
# /model/decoder/layers.1/encoder_attn/Reshape_2 Reshape
# /model/decoder/layers.1/encoder_attn/Transpose_1 Transpose
# /model/decoder/layers.1/encoder_attn/Transpose_2 Transpose
# /model/decoder/layers.1/encoder_attn/MatMul MatMul
# /model/decoder/layers.1/encoder_attn/Softmax Softmax
# /model/decoder/layers.1/encoder_attn/MatMul_1 MatMul
# /model/decoder/layers.1/encoder_attn/Transpose_3 Transpose
# Constant_1995 Constant
# /model/decoder/layers.1/encoder_attn/Unsqueeze_4 Unsqueeze
# Constant_1997 Constant
# /model/decoder/layers.1/encoder_attn/Unsqueeze_5 Unsqueeze
# /model/decoder/layers.1/encoder_attn/Constant_11 Constant
# /model/decoder/layers.1/encoder_attn/Concat_3 Concat
# /model/decoder/layers.1/encoder_attn/Reshape_3 Reshape
# /model/decoder/layers.1/encoder_attn/out_proj/MatMul MatMul
# /model/decoder/layers.1/encoder_attn/out_proj/Add Add
# /model/decoder/layers.1/Add_1 Add
# /model/decoder/layers.1/final_layer_norm/ReduceMean ReduceMean
# /model/decoder/layers.1/final_layer_norm/Sub Sub
# /model/decoder/layers.1/final_layer_norm/Constant Constant
# /model/decoder/layers.1/final_layer_norm/Pow Pow
# /model/decoder/layers.1/final_layer_norm/ReduceMean_1 ReduceMean
# /model/decoder/layers.1/final_layer_norm/Constant_1 Constant
# /model/decoder/layers.1/final_layer_norm/Add Add
# /model/decoder/layers.1/final_layer_norm/Sqrt Sqrt
# /model/decoder/layers.1/final_layer_norm/Div Div
# /model/decoder/layers.1/final_layer_norm/Mul Mul
# /model/decoder/layers.1/final_layer_norm/Add_1 Add
# /model/decoder/layers.1/fc1/MatMul MatMul
# /model/decoder/layers.1/fc1/Add Add
# /model/decoder/layers.1/activation_fn/Constant Constant
# /model/decoder/layers.1/activation_fn/Div Div
# /model/decoder/layers.1/activation_fn/Erf Erf
# /model/decoder/layers.1/activation_fn/Constant_1 Constant
# /model/decoder/layers.1/activation_fn/Add Add
# /model/decoder/layers.1/activation_fn/Mul Mul
# /model/decoder/layers.1/activation_fn/Constant_2 Constant
# /model/decoder/layers.1/activation_fn/Mul_1 Mul
# /model/decoder/layers.1/fc2/MatMul MatMul
# /model/decoder/layers.1/fc2/Add Add
# /model/decoder/layers.1/Add_2 Add
# /model/decoder/layers.2/self_attn_layer_norm/ReduceMean ReduceMean
# /model/decoder/layers.2/self_attn_layer_norm/Sub Sub
# /model/decoder/layers.2/self_attn_layer_norm/Constant Constant
# /model/decoder/layers.2/self_attn_layer_norm/Pow Pow
# /model/decoder/layers.2/self_attn_layer_norm/ReduceMean_1 ReduceMean
# /model/decoder/layers.2/self_attn_layer_norm/Constant_1 Constant
# /model/decoder/layers.2/self_attn_layer_norm/Add Add
# /model/decoder/layers.2/self_attn_layer_norm/Sqrt Sqrt
# /model/decoder/layers.2/self_attn_layer_norm/Div Div
# /model/decoder/layers.2/self_attn_layer_norm/Mul Mul
# /model/decoder/layers.2/self_attn_layer_norm/Add_1 Add
# /model/decoder/layers.2/self_attn/Shape Shape
# /model/decoder/layers.2/self_attn/Constant Constant
# /model/decoder/layers.2/self_attn/Gather Gather
# /model/decoder/layers.2/self_attn/Shape_1 Shape
# /model/decoder/layers.2/self_attn/Constant_1 Constant
# /model/decoder/layers.2/self_attn/Gather_1 Gather
# /model/decoder/layers.2/self_attn/q_proj/MatMul MatMul
# /model/decoder/layers.2/self_attn/q_proj/Add Add
# /model/decoder/layers.2/self_attn/Constant_2 Constant
# /model/decoder/layers.2/self_attn/Mul Mul
# Constant_2050 Constant
# /model/decoder/layers.2/self_attn/Unsqueeze Unsqueeze
# Constant_2052 Constant
# /model/decoder/layers.2/self_attn/Unsqueeze_1 Unsqueeze
# /model/decoder/layers.2/self_attn/Constant_3 Constant
# /model/decoder/layers.2/self_attn/Constant_4 Constant
# /model/decoder/layers.2/self_attn/Concat Concat
# /model/decoder/layers.2/self_attn/Reshape Reshape
# /model/decoder/layers.2/self_attn/Transpose Transpose
# /model/decoder/layers.2/self_attn/k_proj/MatMul MatMul
# Constant_2060 Constant
# /model/decoder/layers.2/self_attn/Unsqueeze_2 Unsqueeze
# /model/decoder/layers.2/self_attn/Constant_5 Constant
# /model/decoder/layers.2/self_attn/Constant_6 Constant
# /model/decoder/layers.2/self_attn/Constant_7 Constant
# /model/decoder/layers.2/self_attn/Concat_1 Concat
# Constant_2066 Constant
# /model/decoder/layers.2/self_attn/Unsqueeze_3 Unsqueeze
# /model/decoder/layers.2/self_attn/Constant_8 Constant
# /model/decoder/layers.2/self_attn/Constant_9 Constant
# /model/decoder/layers.2/self_attn/Constant_10 Constant
# /model/decoder/layers.2/self_attn/Concat_2 Concat
# /model/decoder/layers.2/self_attn/Reshape_1 Reshape
# /model/decoder/layers.2/self_attn/Transpose_1 Transpose
# /model/decoder/layers.2/self_attn/v_proj/MatMul MatMul
# /model/decoder/layers.2/self_attn/v_proj/Add Add
# /model/decoder/layers.2/self_attn/Reshape_2 Reshape
# /model/decoder/layers.2/self_attn/Transpose_2 Transpose
# /model/decoder/layers.2/self_attn/Transpose_3 Transpose
# /model/decoder/layers.2/self_attn/MatMul MatMul
# /model/decoder/layers.2/self_attn/Shape_2 Shape
# /model/decoder/layers.2/self_attn/Constant_11 Constant
# /model/decoder/layers.2/self_attn/Gather_2 Gather
# /model/decoder/layers.2/self_attn/Constant_12 Constant
# /model/decoder/layers.2/self_attn/Constant_13 Constant
# /model/decoder/layers.2/self_attn/Constant_14 Constant
# /model/decoder/layers.2/self_attn/Unsqueeze_4 Unsqueeze
# /model/decoder/layers.2/self_attn/Constant_15 Constant
# /model/decoder/layers.2/self_attn/Slice Slice
# /model/decoder/layers.2/self_attn/Add Add
# /model/decoder/layers.2/self_attn/Softmax Softmax
# /model/decoder/layers.2/self_attn/MatMul_1 MatMul
# /model/decoder/layers.2/self_attn/Transpose_4 Transpose
# Constant_2093 Constant
# /model/decoder/layers.2/self_attn/Unsqueeze_5 Unsqueeze
# Constant_2095 Constant
# /model/decoder/layers.2/self_attn/Unsqueeze_6 Unsqueeze
# /model/decoder/layers.2/self_attn/Constant_16 Constant
# /model/decoder/layers.2/self_attn/Concat_3 Concat
# /model/decoder/layers.2/self_attn/Reshape_3 Reshape
# /model/decoder/layers.2/self_attn/out_proj/MatMul MatMul
# /model/decoder/layers.2/self_attn/out_proj/Add Add
# /model/decoder/layers.2/Add Add
# /model/decoder/layers.2/encoder_attn_layer_norm/ReduceMean ReduceMean
# /model/decoder/layers.2/encoder_attn_layer_norm/Sub Sub
# /model/decoder/layers.2/encoder_attn_layer_norm/Constant Constant
# /model/decoder/layers.2/encoder_attn_layer_norm/Pow Pow
# /model/decoder/layers.2/encoder_attn_layer_norm/ReduceMean_1 ReduceMean
# /model/decoder/layers.2/encoder_attn_layer_norm/Constant_1 Constant
# /model/decoder/layers.2/encoder_attn_layer_norm/Add Add
# /model/decoder/layers.2/encoder_attn_layer_norm/Sqrt Sqrt
# /model/decoder/layers.2/encoder_attn_layer_norm/Div Div
# /model/decoder/layers.2/encoder_attn_layer_norm/Mul Mul
# /model/decoder/layers.2/encoder_attn_layer_norm/Add_1 Add
# /model/decoder/layers.2/encoder_attn/Shape Shape
# /model/decoder/layers.2/encoder_attn/Constant Constant
# /model/decoder/layers.2/encoder_attn/Gather Gather
# /model/decoder/layers.2/encoder_attn/Shape_1 Shape
# /model/decoder/layers.2/encoder_attn/Constant_1 Constant
# /model/decoder/layers.2/encoder_attn/Gather_1 Gather
# /model/decoder/layers.2/encoder_attn/q_proj/MatMul MatMul
# /model/decoder/layers.2/encoder_attn/q_proj/Add Add
# /model/decoder/layers.2/encoder_attn/Constant_2 Constant
# /model/decoder/layers.2/encoder_attn/Mul Mul
# Constant_2124 Constant
# /model/decoder/layers.2/encoder_attn/Unsqueeze Unsqueeze
# Constant_2126 Constant
# /model/decoder/layers.2/encoder_attn/Unsqueeze_1 Unsqueeze
# /model/decoder/layers.2/encoder_attn/Constant_3 Constant
# /model/decoder/layers.2/encoder_attn/Constant_4 Constant
# /model/decoder/layers.2/encoder_attn/Concat Concat
# /model/decoder/layers.2/encoder_attn/Reshape Reshape
# /model/decoder/layers.2/encoder_attn/Transpose Transpose
# /model/decoder/layers.2/encoder_attn/k_proj/MatMul MatMul
# Constant_2134 Constant
# /model/decoder/layers.2/encoder_attn/Unsqueeze_2 Unsqueeze
# /model/decoder/layers.2/encoder_attn/Constant_5 Constant
# /model/decoder/layers.2/encoder_attn/Constant_6 Constant
# /model/decoder/layers.2/encoder_attn/Constant_7 Constant
# /model/decoder/layers.2/encoder_attn/Concat_1 Concat
# Constant_2140 Constant
# /model/decoder/layers.2/encoder_attn/Unsqueeze_3 Unsqueeze
# /model/decoder/layers.2/encoder_attn/Constant_8 Constant
# /model/decoder/layers.2/encoder_attn/Constant_9 Constant
# /model/decoder/layers.2/encoder_attn/Constant_10 Constant
# /model/decoder/layers.2/encoder_attn/Concat_2 Concat
# /model/decoder/layers.2/encoder_attn/Reshape_1 Reshape
# /model/decoder/layers.2/encoder_attn/v_proj/MatMul MatMul
# /model/decoder/layers.2/encoder_attn/v_proj/Add Add
# /model/decoder/layers.2/encoder_attn/Reshape_2 Reshape
# /model/decoder/layers.2/encoder_attn/Transpose_1 Transpose
# /model/decoder/layers.2/encoder_attn/Transpose_2 Transpose
# /model/decoder/layers.2/encoder_attn/MatMul MatMul
# /model/decoder/layers.2/encoder_attn/Softmax Softmax
# /model/decoder/layers.2/encoder_attn/MatMul_1 MatMul
# /model/decoder/layers.2/encoder_attn/Transpose_3 Transpose
# Constant_2156 Constant
# /model/decoder/layers.2/encoder_attn/Unsqueeze_4 Unsqueeze
# Constant_2158 Constant
# /model/decoder/layers.2/encoder_attn/Unsqueeze_5 Unsqueeze
# /model/decoder/layers.2/encoder_attn/Constant_11 Constant
# /model/decoder/layers.2/encoder_attn/Concat_3 Concat
# /model/decoder/layers.2/encoder_attn/Reshape_3 Reshape
# /model/decoder/layers.2/encoder_attn/out_proj/MatMul MatMul
# /model/decoder/layers.2/encoder_attn/out_proj/Add Add
# /model/decoder/layers.2/Add_1 Add
# /model/decoder/layers.2/final_layer_norm/ReduceMean ReduceMean
# /model/decoder/layers.2/final_layer_norm/Sub Sub
# /model/decoder/layers.2/final_layer_norm/Constant Constant
# /model/decoder/layers.2/final_layer_norm/Pow Pow
# /model/decoder/layers.2/final_layer_norm/ReduceMean_1 ReduceMean
# /model/decoder/layers.2/final_layer_norm/Constant_1 Constant
# /model/decoder/layers.2/final_layer_norm/Add Add
# /model/decoder/layers.2/final_layer_norm/Sqrt Sqrt
# /model/decoder/layers.2/final_layer_norm/Div Div
# /model/decoder/layers.2/final_layer_norm/Mul Mul
# /model/decoder/layers.2/final_layer_norm/Add_1 Add
# /model/decoder/layers.2/fc1/MatMul MatMul
# /model/decoder/layers.2/fc1/Add Add
# /model/decoder/layers.2/activation_fn/Constant Constant
# /model/decoder/layers.2/activation_fn/Div Div
# /model/decoder/layers.2/activation_fn/Erf Erf
# /model/decoder/layers.2/activation_fn/Constant_1 Constant
# /model/decoder/layers.2/activation_fn/Add Add
# /model/decoder/layers.2/activation_fn/Mul Mul
# /model/decoder/layers.2/activation_fn/Constant_2 Constant
# /model/decoder/layers.2/activation_fn/Mul_1 Mul
# /model/decoder/layers.2/fc2/MatMul MatMul
# /model/decoder/layers.2/fc2/Add Add
# /model/decoder/layers.2/Add_2 Add
# /model/decoder/layers.3/self_attn_layer_norm/ReduceMean ReduceMean
# /model/decoder/layers.3/self_attn_layer_norm/Sub Sub
# /model/decoder/layers.3/self_attn_layer_norm/Constant Constant
# /model/decoder/layers.3/self_attn_layer_norm/Pow Pow
# /model/decoder/layers.3/self_attn_layer_norm/ReduceMean_1 ReduceMean
# /model/decoder/layers.3/self_attn_layer_norm/Constant_1 Constant
# /model/decoder/layers.3/self_attn_layer_norm/Add Add
# /model/decoder/layers.3/self_attn_layer_norm/Sqrt Sqrt
# /model/decoder/layers.3/self_attn_layer_norm/Div Div
# /model/decoder/layers.3/self_attn_layer_norm/Mul Mul
# /model/decoder/layers.3/self_attn_layer_norm/Add_1 Add
# /model/decoder/layers.3/self_attn/Shape Shape
# /model/decoder/layers.3/self_attn/Constant Constant
# /model/decoder/layers.3/self_attn/Gather Gather
# /model/decoder/layers.3/self_attn/Shape_1 Shape
# /model/decoder/layers.3/self_attn/Constant_1 Constant
# /model/decoder/layers.3/self_attn/Gather_1 Gather
# /model/decoder/layers.3/self_attn/q_proj/MatMul MatMul
# /model/decoder/layers.3/self_attn/q_proj/Add Add
# /model/decoder/layers.3/self_attn/Constant_2 Constant
# /model/decoder/layers.3/self_attn/Mul Mul
# Constant_2211 Constant
# /model/decoder/layers.3/self_attn/Unsqueeze Unsqueeze
# Constant_2213 Constant
# /model/decoder/layers.3/self_attn/Unsqueeze_1 Unsqueeze
# /model/decoder/layers.3/self_attn/Constant_3 Constant
# /model/decoder/layers.3/self_attn/Constant_4 Constant
# /model/decoder/layers.3/self_attn/Concat Concat
# /model/decoder/layers.3/self_attn/Reshape Reshape
# /model/decoder/layers.3/self_attn/Transpose Transpose
# /model/decoder/layers.3/self_attn/k_proj/MatMul MatMul
# Constant_2221 Constant
# /model/decoder/layers.3/self_attn/Unsqueeze_2 Unsqueeze
# /model/decoder/layers.3/self_attn/Constant_5 Constant
# /model/decoder/layers.3/self_attn/Constant_6 Constant
# /model/decoder/layers.3/self_attn/Constant_7 Constant
# /model/decoder/layers.3/self_attn/Concat_1 Concat
# Constant_2227 Constant
# /model/decoder/layers.3/self_attn/Unsqueeze_3 Unsqueeze
# /model/decoder/layers.3/self_attn/Constant_8 Constant
# /model/decoder/layers.3/self_attn/Constant_9 Constant
# /model/decoder/layers.3/self_attn/Constant_10 Constant
# /model/decoder/layers.3/self_attn/Concat_2 Concat
# /model/decoder/layers.3/self_attn/Reshape_1 Reshape
# /model/decoder/layers.3/self_attn/Transpose_1 Transpose
# /model/decoder/layers.3/self_attn/v_proj/MatMul MatMul
# /model/decoder/layers.3/self_attn/v_proj/Add Add
# /model/decoder/layers.3/self_attn/Reshape_2 Reshape
# /model/decoder/layers.3/self_attn/Transpose_2 Transpose
# /model/decoder/layers.3/self_attn/Transpose_3 Transpose
# /model/decoder/layers.3/self_attn/MatMul MatMul
# /model/decoder/layers.3/self_attn/Shape_2 Shape
# /model/decoder/layers.3/self_attn/Constant_11 Constant
# /model/decoder/layers.3/self_attn/Gather_2 Gather
# /model/decoder/layers.3/self_attn/Constant_12 Constant
# /model/decoder/layers.3/self_attn/Constant_13 Constant
# /model/decoder/layers.3/self_attn/Constant_14 Constant
# /model/decoder/layers.3/self_attn/Unsqueeze_4 Unsqueeze
# /model/decoder/layers.3/self_attn/Constant_15 Constant
# /model/decoder/layers.3/self_attn/Slice Slice
# /model/decoder/layers.3/self_attn/Add Add
# /model/decoder/layers.3/self_attn/Softmax Softmax
# /model/decoder/layers.3/self_attn/MatMul_1 MatMul
# /model/decoder/layers.3/self_attn/Transpose_4 Transpose
# Constant_2254 Constant
# /model/decoder/layers.3/self_attn/Unsqueeze_5 Unsqueeze
# Constant_2256 Constant
# /model/decoder/layers.3/self_attn/Unsqueeze_6 Unsqueeze
# /model/decoder/layers.3/self_attn/Constant_16 Constant
# /model/decoder/layers.3/self_attn/Concat_3 Concat
# /model/decoder/layers.3/self_attn/Reshape_3 Reshape
# /model/decoder/layers.3/self_attn/out_proj/MatMul MatMul
# /model/decoder/layers.3/self_attn/out_proj/Add Add
# /model/decoder/layers.3/Add Add
# /model/decoder/layers.3/encoder_attn_layer_norm/ReduceMean ReduceMean
# /model/decoder/layers.3/encoder_attn_layer_norm/Sub Sub
# /model/decoder/layers.3/encoder_attn_layer_norm/Constant Constant
# /model/decoder/layers.3/encoder_attn_layer_norm/Pow Pow
# /model/decoder/layers.3/encoder_attn_layer_norm/ReduceMean_1 ReduceMean
# /model/decoder/layers.3/encoder_attn_layer_norm/Constant_1 Constant
# /model/decoder/layers.3/encoder_attn_layer_norm/Add Add
# /model/decoder/layers.3/encoder_attn_layer_norm/Sqrt Sqrt
# /model/decoder/layers.3/encoder_attn_layer_norm/Div Div
# /model/decoder/layers.3/encoder_attn_layer_norm/Mul Mul
# /model/decoder/layers.3/encoder_attn_layer_norm/Add_1 Add
# /model/decoder/layers.3/encoder_attn/Shape Shape
# /model/decoder/layers.3/encoder_attn/Constant Constant
# /model/decoder/layers.3/encoder_attn/Gather Gather
# /model/decoder/layers.3/encoder_attn/Shape_1 Shape
# /model/decoder/layers.3/encoder_attn/Constant_1 Constant
# /model/decoder/layers.3/encoder_attn/Gather_1 Gather
# /model/decoder/layers.3/encoder_attn/q_proj/MatMul MatMul
# /model/decoder/layers.3/encoder_attn/q_proj/Add Add
# /model/decoder/layers.3/encoder_attn/Constant_2 Constant
# /model/decoder/layers.3/encoder_attn/Mul Mul
# Constant_2285 Constant
# /model/decoder/layers.3/encoder_attn/Unsqueeze Unsqueeze
# Constant_2287 Constant
# /model/decoder/layers.3/encoder_attn/Unsqueeze_1 Unsqueeze
# /model/decoder/layers.3/encoder_attn/Constant_3 Constant
# /model/decoder/layers.3/encoder_attn/Constant_4 Constant
# /model/decoder/layers.3/encoder_attn/Concat Concat
# /model/decoder/layers.3/encoder_attn/Reshape Reshape
# /model/decoder/layers.3/encoder_attn/Transpose Transpose
# /model/decoder/layers.3/encoder_attn/k_proj/MatMul MatMul
# Constant_2295 Constant
# /model/decoder/layers.3/encoder_attn/Unsqueeze_2 Unsqueeze
# /model/decoder/layers.3/encoder_attn/Constant_5 Constant
# /model/decoder/layers.3/encoder_attn/Constant_6 Constant
# /model/decoder/layers.3/encoder_attn/Constant_7 Constant
# /model/decoder/layers.3/encoder_attn/Concat_1 Concat
# Constant_2301 Constant
# /model/decoder/layers.3/encoder_attn/Unsqueeze_3 Unsqueeze
# /model/decoder/layers.3/encoder_attn/Constant_8 Constant
# /model/decoder/layers.3/encoder_attn/Constant_9 Constant
# /model/decoder/layers.3/encoder_attn/Constant_10 Constant
# /model/decoder/layers.3/encoder_attn/Concat_2 Concat
# /model/decoder/layers.3/encoder_attn/Reshape_1 Reshape
# /model/decoder/layers.3/encoder_attn/v_proj/MatMul MatMul
# /model/decoder/layers.3/encoder_attn/v_proj/Add Add
# /model/decoder/layers.3/encoder_attn/Reshape_2 Reshape
# /model/decoder/layers.3/encoder_attn/Transpose_1 Transpose
# /model/decoder/layers.3/encoder_attn/Transpose_2 Transpose
# /model/decoder/layers.3/encoder_attn/MatMul MatMul
# /model/decoder/layers.3/encoder_attn/Softmax Softmax
# /model/decoder/layers.3/encoder_attn/MatMul_1 MatMul
# /model/decoder/layers.3/encoder_attn/Transpose_3 Transpose
# Constant_2317 Constant
# /model/decoder/layers.3/encoder_attn/Unsqueeze_4 Unsqueeze
# Constant_2319 Constant
# /model/decoder/layers.3/encoder_attn/Unsqueeze_5 Unsqueeze
# /model/decoder/layers.3/encoder_attn/Constant_11 Constant
# /model/decoder/layers.3/encoder_attn/Concat_3 Concat
# /model/decoder/layers.3/encoder_attn/Reshape_3 Reshape
# /model/decoder/layers.3/encoder_attn/out_proj/MatMul MatMul
# /model/decoder/layers.3/encoder_attn/out_proj/Add Add
# /model/decoder/layers.3/Add_1 Add
# /model/decoder/layers.3/final_layer_norm/ReduceMean ReduceMean
# /model/decoder/layers.3/final_layer_norm/Sub Sub
# /model/decoder/layers.3/final_layer_norm/Constant Constant
# /model/decoder/layers.3/final_layer_norm/Pow Pow
# /model/decoder/layers.3/final_layer_norm/ReduceMean_1 ReduceMean
# /model/decoder/layers.3/final_layer_norm/Constant_1 Constant
# /model/decoder/layers.3/final_layer_norm/Add Add
# /model/decoder/layers.3/final_layer_norm/Sqrt Sqrt
# /model/decoder/layers.3/final_layer_norm/Div Div
# /model/decoder/layers.3/final_layer_norm/Mul Mul
# /model/decoder/layers.3/final_layer_norm/Add_1 Add
# /model/decoder/layers.3/fc1/MatMul MatMul
# /model/decoder/layers.3/fc1/Add Add
# /model/decoder/layers.3/activation_fn/Constant Constant
# /model/decoder/layers.3/activation_fn/Div Div
# /model/decoder/layers.3/activation_fn/Erf Erf
# /model/decoder/layers.3/activation_fn/Constant_1 Constant
# /model/decoder/layers.3/activation_fn/Add Add
# /model/decoder/layers.3/activation_fn/Mul Mul
# /model/decoder/layers.3/activation_fn/Constant_2 Constant
# /model/decoder/layers.3/activation_fn/Mul_1 Mul
# /model/decoder/layers.3/fc2/MatMul MatMul
# /model/decoder/layers.3/fc2/Add Add
# /model/decoder/layers.3/Add_2 Add
# /model/decoder/layers.4/self_attn_layer_norm/ReduceMean ReduceMean
# /model/decoder/layers.4/self_attn_layer_norm/Sub Sub
# /model/decoder/layers.4/self_attn_layer_norm/Constant Constant
# /model/decoder/layers.4/self_attn_layer_norm/Pow Pow
# /model/decoder/layers.4/self_attn_layer_norm/ReduceMean_1 ReduceMean
# /model/decoder/layers.4/self_attn_layer_norm/Constant_1 Constant
# /model/decoder/layers.4/self_attn_layer_norm/Add Add
# /model/decoder/layers.4/self_attn_layer_norm/Sqrt Sqrt
# /model/decoder/layers.4/self_attn_layer_norm/Div Div
# /model/decoder/layers.4/self_attn_layer_norm/Mul Mul
# /model/decoder/layers.4/self_attn_layer_norm/Add_1 Add
# /model/decoder/layers.4/self_attn/Shape Shape
# /model/decoder/layers.4/self_attn/Constant Constant
# /model/decoder/layers.4/self_attn/Gather Gather
# /model/decoder/layers.4/self_attn/Shape_1 Shape
# /model/decoder/layers.4/self_attn/Constant_1 Constant
# /model/decoder/layers.4/self_attn/Gather_1 Gather
# /model/decoder/layers.4/self_attn/q_proj/MatMul MatMul
# /model/decoder/layers.4/self_attn/q_proj/Add Add
# /model/decoder/layers.4/self_attn/Constant_2 Constant
# /model/decoder/layers.4/self_attn/Mul Mul
# Constant_2372 Constant
# /model/decoder/layers.4/self_attn/Unsqueeze Unsqueeze
# Constant_2374 Constant
# /model/decoder/layers.4/self_attn/Unsqueeze_1 Unsqueeze
# /model/decoder/layers.4/self_attn/Constant_3 Constant
# /model/decoder/layers.4/self_attn/Constant_4 Constant
# /model/decoder/layers.4/self_attn/Concat Concat
# /model/decoder/layers.4/self_attn/Reshape Reshape
# /model/decoder/layers.4/self_attn/Transpose Transpose
# /model/decoder/layers.4/self_attn/k_proj/MatMul MatMul
# Constant_2382 Constant
# /model/decoder/layers.4/self_attn/Unsqueeze_2 Unsqueeze
# /model/decoder/layers.4/self_attn/Constant_5 Constant
# /model/decoder/layers.4/self_attn/Constant_6 Constant
# /model/decoder/layers.4/self_attn/Constant_7 Constant
# /model/decoder/layers.4/self_attn/Concat_1 Concat
# Constant_2388 Constant
# /model/decoder/layers.4/self_attn/Unsqueeze_3 Unsqueeze
# /model/decoder/layers.4/self_attn/Constant_8 Constant
# /model/decoder/layers.4/self_attn/Constant_9 Constant
# /model/decoder/layers.4/self_attn/Constant_10 Constant
# /model/decoder/layers.4/self_attn/Concat_2 Concat
# /model/decoder/layers.4/self_attn/Reshape_1 Reshape
# /model/decoder/layers.4/self_attn/Transpose_1 Transpose
# /model/decoder/layers.4/self_attn/v_proj/MatMul MatMul
# /model/decoder/layers.4/self_attn/v_proj/Add Add
# /model/decoder/layers.4/self_attn/Reshape_2 Reshape
# /model/decoder/layers.4/self_attn/Transpose_2 Transpose
# /model/decoder/layers.4/self_attn/Transpose_3 Transpose
# /model/decoder/layers.4/self_attn/MatMul MatMul
# /model/decoder/layers.4/self_attn/Shape_2 Shape
# /model/decoder/layers.4/self_attn/Constant_11 Constant
# /model/decoder/layers.4/self_attn/Gather_2 Gather
# /model/decoder/layers.4/self_attn/Constant_12 Constant
# /model/decoder/layers.4/self_attn/Constant_13 Constant
# /model/decoder/layers.4/self_attn/Constant_14 Constant
# /model/decoder/layers.4/self_attn/Unsqueeze_4 Unsqueeze
# /model/decoder/layers.4/self_attn/Constant_15 Constant
# /model/decoder/layers.4/self_attn/Slice Slice
# /model/decoder/layers.4/self_attn/Add Add
# /model/decoder/layers.4/self_attn/Softmax Softmax
# /model/decoder/layers.4/self_attn/MatMul_1 MatMul
# /model/decoder/layers.4/self_attn/Transpose_4 Transpose
# Constant_2415 Constant
# /model/decoder/layers.4/self_attn/Unsqueeze_5 Unsqueeze
# Constant_2417 Constant
# /model/decoder/layers.4/self_attn/Unsqueeze_6 Unsqueeze
# /model/decoder/layers.4/self_attn/Constant_16 Constant
# /model/decoder/layers.4/self_attn/Concat_3 Concat
# /model/decoder/layers.4/self_attn/Reshape_3 Reshape
# /model/decoder/layers.4/self_attn/out_proj/MatMul MatMul
# /model/decoder/layers.4/self_attn/out_proj/Add Add
# /model/decoder/layers.4/Add Add
# /model/decoder/layers.4/encoder_attn_layer_norm/ReduceMean ReduceMean
# /model/decoder/layers.4/encoder_attn_layer_norm/Sub Sub
# /model/decoder/layers.4/encoder_attn_layer_norm/Constant Constant
# /model/decoder/layers.4/encoder_attn_layer_norm/Pow Pow
# /model/decoder/layers.4/encoder_attn_layer_norm/ReduceMean_1 ReduceMean
# /model/decoder/layers.4/encoder_attn_layer_norm/Constant_1 Constant
# /model/decoder/layers.4/encoder_attn_layer_norm/Add Add
# /model/decoder/layers.4/encoder_attn_layer_norm/Sqrt Sqrt
# /model/decoder/layers.4/encoder_attn_layer_norm/Div Div
# /model/decoder/layers.4/encoder_attn_layer_norm/Mul Mul
# /model/decoder/layers.4/encoder_attn_layer_norm/Add_1 Add
# /model/decoder/layers.4/encoder_attn/Shape Shape
# /model/decoder/layers.4/encoder_attn/Constant Constant
# /model/decoder/layers.4/encoder_attn/Gather Gather
# /model/decoder/layers.4/encoder_attn/Shape_1 Shape
# /model/decoder/layers.4/encoder_attn/Constant_1 Constant
# /model/decoder/layers.4/encoder_attn/Gather_1 Gather
# /model/decoder/layers.4/encoder_attn/q_proj/MatMul MatMul
# /model/decoder/layers.4/encoder_attn/q_proj/Add Add
# /model/decoder/layers.4/encoder_attn/Constant_2 Constant
# /model/decoder/layers.4/encoder_attn/Mul Mul
# Constant_2446 Constant
# /model/decoder/layers.4/encoder_attn/Unsqueeze Unsqueeze
# Constant_2448 Constant
# /model/decoder/layers.4/encoder_attn/Unsqueeze_1 Unsqueeze
# /model/decoder/layers.4/encoder_attn/Constant_3 Constant
# /model/decoder/layers.4/encoder_attn/Constant_4 Constant
# /model/decoder/layers.4/encoder_attn/Concat Concat
# /model/decoder/layers.4/encoder_attn/Reshape Reshape
# /model/decoder/layers.4/encoder_attn/Transpose Transpose
# /model/decoder/layers.4/encoder_attn/k_proj/MatMul MatMul
# Constant_2456 Constant
# /model/decoder/layers.4/encoder_attn/Unsqueeze_2 Unsqueeze
# /model/decoder/layers.4/encoder_attn/Constant_5 Constant
# /model/decoder/layers.4/encoder_attn/Constant_6 Constant
# /model/decoder/layers.4/encoder_attn/Constant_7 Constant
# /model/decoder/layers.4/encoder_attn/Concat_1 Concat
# Constant_2462 Constant
# /model/decoder/layers.4/encoder_attn/Unsqueeze_3 Unsqueeze
# /model/decoder/layers.4/encoder_attn/Constant_8 Constant
# /model/decoder/layers.4/encoder_attn/Constant_9 Constant
# /model/decoder/layers.4/encoder_attn/Constant_10 Constant
# /model/decoder/layers.4/encoder_attn/Concat_2 Concat
# /model/decoder/layers.4/encoder_attn/Reshape_1 Reshape
# /model/decoder/layers.4/encoder_attn/v_proj/MatMul MatMul
# /model/decoder/layers.4/encoder_attn/v_proj/Add Add
# /model/decoder/layers.4/encoder_attn/Reshape_2 Reshape
# /model/decoder/layers.4/encoder_attn/Transpose_1 Transpose
# /model/decoder/layers.4/encoder_attn/Transpose_2 Transpose
# /model/decoder/layers.4/encoder_attn/MatMul MatMul
# /model/decoder/layers.4/encoder_attn/Softmax Softmax
# /model/decoder/layers.4/encoder_attn/MatMul_1 MatMul
# /model/decoder/layers.4/encoder_attn/Transpose_3 Transpose
# Constant_2478 Constant
# /model/decoder/layers.4/encoder_attn/Unsqueeze_4 Unsqueeze
# Constant_2480 Constant
# /model/decoder/layers.4/encoder_attn/Unsqueeze_5 Unsqueeze
# /model/decoder/layers.4/encoder_attn/Constant_11 Constant
# /model/decoder/layers.4/encoder_attn/Concat_3 Concat
# /model/decoder/layers.4/encoder_attn/Reshape_3 Reshape
# /model/decoder/layers.4/encoder_attn/out_proj/MatMul MatMul
# /model/decoder/layers.4/encoder_attn/out_proj/Add Add
# /model/decoder/layers.4/Add_1 Add
# /model/decoder/layers.4/final_layer_norm/ReduceMean ReduceMean
# /model/decoder/layers.4/final_layer_norm/Sub Sub
# /model/decoder/layers.4/final_layer_norm/Constant Constant
# /model/decoder/layers.4/final_layer_norm/Pow Pow
# /model/decoder/layers.4/final_layer_norm/ReduceMean_1 ReduceMean
# /model/decoder/layers.4/final_layer_norm/Constant_1 Constant
# /model/decoder/layers.4/final_layer_norm/Add Add
# /model/decoder/layers.4/final_layer_norm/Sqrt Sqrt
# /model/decoder/layers.4/final_layer_norm/Div Div
# /model/decoder/layers.4/final_layer_norm/Mul Mul
# /model/decoder/layers.4/final_layer_norm/Add_1 Add
# /model/decoder/layers.4/fc1/MatMul MatMul
# /model/decoder/layers.4/fc1/Add Add
# /model/decoder/layers.4/activation_fn/Constant Constant
# /model/decoder/layers.4/activation_fn/Div Div
# /model/decoder/layers.4/activation_fn/Erf Erf
# /model/decoder/layers.4/activation_fn/Constant_1 Constant
# /model/decoder/layers.4/activation_fn/Add Add
# /model/decoder/layers.4/activation_fn/Mul Mul
# /model/decoder/layers.4/activation_fn/Constant_2 Constant
# /model/decoder/layers.4/activation_fn/Mul_1 Mul
# /model/decoder/layers.4/fc2/MatMul MatMul
# /model/decoder/layers.4/fc2/Add Add
# /model/decoder/layers.4/Add_2 Add
# /model/decoder/layers.5/self_attn_layer_norm/ReduceMean ReduceMean
# /model/decoder/layers.5/self_attn_layer_norm/Sub Sub
# /model/decoder/layers.5/self_attn_layer_norm/Constant Constant
# /model/decoder/layers.5/self_attn_layer_norm/Pow Pow
# /model/decoder/layers.5/self_attn_layer_norm/ReduceMean_1 ReduceMean
# /model/decoder/layers.5/self_attn_layer_norm/Constant_1 Constant
# /model/decoder/layers.5/self_attn_layer_norm/Add Add
# /model/decoder/layers.5/self_attn_layer_norm/Sqrt Sqrt
# /model/decoder/layers.5/self_attn_layer_norm/Div Div
# /model/decoder/layers.5/self_attn_layer_norm/Mul Mul
# /model/decoder/layers.5/self_attn_layer_norm/Add_1 Add
# /model/decoder/layers.5/self_attn/Shape Shape
# /model/decoder/layers.5/self_attn/Constant Constant
# /model/decoder/layers.5/self_attn/Gather Gather
# /model/decoder/layers.5/self_attn/Shape_1 Shape
# /model/decoder/layers.5/self_attn/Constant_1 Constant
# /model/decoder/layers.5/self_attn/Gather_1 Gather
# /model/decoder/layers.5/self_attn/q_proj/MatMul MatMul
# /model/decoder/layers.5/self_attn/q_proj/Add Add
# /model/decoder/layers.5/self_attn/Constant_2 Constant
# /model/decoder/layers.5/self_attn/Mul Mul
# Constant_2533 Constant
# /model/decoder/layers.5/self_attn/Unsqueeze Unsqueeze
# Constant_2535 Constant
# /model/decoder/layers.5/self_attn/Unsqueeze_1 Unsqueeze
# /model/decoder/layers.5/self_attn/Constant_3 Constant
# /model/decoder/layers.5/self_attn/Constant_4 Constant
# /model/decoder/layers.5/self_attn/Concat Concat
# /model/decoder/layers.5/self_attn/Reshape Reshape
# /model/decoder/layers.5/self_attn/Transpose Transpose
# /model/decoder/layers.5/self_attn/k_proj/MatMul MatMul
# Constant_2543 Constant
# /model/decoder/layers.5/self_attn/Unsqueeze_2 Unsqueeze
# /model/decoder/layers.5/self_attn/Constant_5 Constant
# /model/decoder/layers.5/self_attn/Constant_6 Constant
# /model/decoder/layers.5/self_attn/Constant_7 Constant
# /model/decoder/layers.5/self_attn/Concat_1 Concat
# Constant_2549 Constant
# /model/decoder/layers.5/self_attn/Unsqueeze_3 Unsqueeze
# /model/decoder/layers.5/self_attn/Constant_8 Constant
# /model/decoder/layers.5/self_attn/Constant_9 Constant
# /model/decoder/layers.5/self_attn/Constant_10 Constant
# /model/decoder/layers.5/self_attn/Concat_2 Concat
# /model/decoder/layers.5/self_attn/Reshape_1 Reshape
# /model/decoder/layers.5/self_attn/Transpose_1 Transpose
# /model/decoder/layers.5/self_attn/v_proj/MatMul MatMul
# /model/decoder/layers.5/self_attn/v_proj/Add Add
# /model/decoder/layers.5/self_attn/Reshape_2 Reshape
# /model/decoder/layers.5/self_attn/Transpose_2 Transpose
# /model/decoder/layers.5/self_attn/Transpose_3 Transpose
# /model/decoder/layers.5/self_attn/MatMul MatMul
# /model/decoder/layers.5/self_attn/Shape_2 Shape
# /model/decoder/layers.5/self_attn/Constant_11 Constant
# /model/decoder/layers.5/self_attn/Gather_2 Gather
# /model/decoder/layers.5/self_attn/Constant_12 Constant
# /model/decoder/layers.5/self_attn/Constant_13 Constant
# /model/decoder/layers.5/self_attn/Constant_14 Constant
# /model/decoder/layers.5/self_attn/Unsqueeze_4 Unsqueeze
# /model/decoder/layers.5/self_attn/Constant_15 Constant
# /model/decoder/layers.5/self_attn/Slice Slice
# /model/decoder/layers.5/self_attn/Add Add
# /model/decoder/layers.5/self_attn/Softmax Softmax
# /model/decoder/layers.5/self_attn/MatMul_1 MatMul
# /model/decoder/layers.5/self_attn/Transpose_4 Transpose
# Constant_2576 Constant
# /model/decoder/layers.5/self_attn/Unsqueeze_5 Unsqueeze
# Constant_2578 Constant
# /model/decoder/layers.5/self_attn/Unsqueeze_6 Unsqueeze
# /model/decoder/layers.5/self_attn/Constant_16 Constant
# /model/decoder/layers.5/self_attn/Concat_3 Concat
# /model/decoder/layers.5/self_attn/Reshape_3 Reshape
# /model/decoder/layers.5/self_attn/out_proj/MatMul MatMul
# /model/decoder/layers.5/self_attn/out_proj/Add Add
# /model/decoder/layers.5/Add Add
# /model/decoder/layers.5/encoder_attn_layer_norm/ReduceMean ReduceMean
# /model/decoder/layers.5/encoder_attn_layer_norm/Sub Sub
# /model/decoder/layers.5/encoder_attn_layer_norm/Constant Constant
# /model/decoder/layers.5/encoder_attn_layer_norm/Pow Pow
# /model/decoder/layers.5/encoder_attn_layer_norm/ReduceMean_1 ReduceMean
# /model/decoder/layers.5/encoder_attn_layer_norm/Constant_1 Constant
# ...
# /model/decoder/layers.30/self_attn/Constant_4 Constant
# /model/decoder/layers.30/self_attn/Concat Concat
# /model/decoder/layers.30/self_attn/Reshape Reshape
# /model/decoder/layers.30/self_attn/Transpose Transpose
# /model/decoder/layers.30/self_attn/k_proj/MatMul MatMul
# Constant_6568 Constant
# /model/decoder/layers.30/self_attn/Unsqueeze_2 Unsqueeze
# /model/decoder/layers.30/self_attn/Constant_5 Constant
# /model/decoder/layers.30/self_attn/Constant_6 Constant
# /model/decoder/layers.30/self_attn/Constant_7 Constant
# /model/decoder/layers.30/self_attn/Concat_1 Concat
# Constant_6574 Constant
# /model/decoder/layers.30/self_attn/Unsqueeze_3 Unsqueeze
# /model/decoder/layers.30/self_attn/Constant_8 Constant
# /model/decoder/layers.30/self_attn/Constant_9 Constant
# /model/decoder/layers.30/self_attn/Constant_10 Constant
# /model/decoder/layers.30/self_attn/Concat_2 Concat
# /model/decoder/layers.30/self_attn/Reshape_1 Reshape
# /model/decoder/layers.30/self_attn/Transpose_1 Transpose
# /model/decoder/layers.30/self_attn/v_proj/MatMul MatMul
# /model/decoder/layers.30/self_attn/v_proj/Add Add
# /model/decoder/layers.30/self_attn/Reshape_2 Reshape
# /model/decoder/layers.30/self_attn/Transpose_2 Transpose
# /model/decoder/layers.30/self_attn/Transpose_3 Transpose
# /model/decoder/layers.30/self_attn/MatMul MatMul
# /model/decoder/layers.30/self_attn/Shape_2 Shape
# /model/decoder/layers.30/self_attn/Constant_11 Constant
# /model/decoder/layers.30/self_attn/Gather_2 Gather
# /model/decoder/layers.30/self_attn/Constant_12 Constant
# /model/decoder/layers.30/self_attn/Constant_13 Constant
# /model/decoder/layers.30/self_attn/Constant_14 Constant
# /model/decoder/layers.30/self_attn/Unsqueeze_4 Unsqueeze
# /model/decoder/layers.30/self_attn/Constant_15 Constant
# /model/decoder/layers.30/self_attn/Slice Slice
# /model/decoder/layers.30/self_attn/Add Add
# /model/decoder/layers.30/self_attn/Softmax Softmax
# /model/decoder/layers.30/self_attn/MatMul_1 MatMul
# /model/decoder/layers.30/self_attn/Transpose_4 Transpose
# Constant_6601 Constant
# /model/decoder/layers.30/self_attn/Unsqueeze_5 Unsqueeze
# Constant_6603 Constant
# /model/decoder/layers.30/self_attn/Unsqueeze_6 Unsqueeze
# /model/decoder/layers.30/self_attn/Constant_16 Constant
# /model/decoder/layers.30/self_attn/Concat_3 Concat
# /model/decoder/layers.30/self_attn/Reshape_3 Reshape
# /model/decoder/layers.30/self_attn/out_proj/MatMul MatMul
# /model/decoder/layers.30/self_attn/out_proj/Add Add
# /model/decoder/layers.30/Add Add
# /model/decoder/layers.30/encoder_attn_layer_norm/ReduceMean ReduceMean
# /model/decoder/layers.30/encoder_attn_layer_norm/Sub Sub
# /model/decoder/layers.30/encoder_attn_layer_norm/Constant Constant
# /model/decoder/layers.30/encoder_attn_layer_norm/Pow Pow
# /model/decoder/layers.30/encoder_attn_layer_norm/ReduceMean_1 ReduceMean
# /model/decoder/layers.30/encoder_attn_layer_norm/Constant_1 Constant
# /model/decoder/layers.30/encoder_attn_layer_norm/Add Add
# /model/decoder/layers.30/encoder_attn_layer_norm/Sqrt Sqrt
# /model/decoder/layers.30/encoder_attn_layer_norm/Div Div
# /model/decoder/layers.30/encoder_attn_layer_norm/Mul Mul
# /model/decoder/layers.30/encoder_attn_layer_norm/Add_1 Add
# /model/decoder/layers.30/encoder_attn/Shape Shape
# /model/decoder/layers.30/encoder_attn/Constant Constant
# /model/decoder/layers.30/encoder_attn/Gather Gather
# /model/decoder/layers.30/encoder_attn/Shape_1 Shape
# /model/decoder/layers.30/encoder_attn/Constant_1 Constant
# /model/decoder/layers.30/encoder_attn/Gather_1 Gather
# /model/decoder/layers.30/encoder_attn/q_proj/MatMul MatMul
# /model/decoder/layers.30/encoder_attn/q_proj/Add Add
# /model/decoder/layers.30/encoder_attn/Constant_2 Constant
# /model/decoder/layers.30/encoder_attn/Mul Mul
# Constant_6632 Constant
# /model/decoder/layers.30/encoder_attn/Unsqueeze Unsqueeze
# Constant_6634 Constant
# /model/decoder/layers.30/encoder_attn/Unsqueeze_1 Unsqueeze
# /model/decoder/layers.30/encoder_attn/Constant_3 Constant
# /model/decoder/layers.30/encoder_attn/Constant_4 Constant
# /model/decoder/layers.30/encoder_attn/Concat Concat
# /model/decoder/layers.30/encoder_attn/Reshape Reshape
# /model/decoder/layers.30/encoder_attn/Transpose Transpose
# /model/decoder/layers.30/encoder_attn/k_proj/MatMul MatMul
# Constant_6642 Constant
# /model/decoder/layers.30/encoder_attn/Unsqueeze_2 Unsqueeze
# /model/decoder/layers.30/encoder_attn/Constant_5 Constant
# /model/decoder/layers.30/encoder_attn/Constant_6 Constant
# /model/decoder/layers.30/encoder_attn/Constant_7 Constant
# /model/decoder/layers.30/encoder_attn/Concat_1 Concat
# Constant_6648 Constant
# /model/decoder/layers.30/encoder_attn/Unsqueeze_3 Unsqueeze
# /model/decoder/layers.30/encoder_attn/Constant_8 Constant
# /model/decoder/layers.30/encoder_attn/Constant_9 Constant
# /model/decoder/layers.30/encoder_attn/Constant_10 Constant
# /model/decoder/layers.30/encoder_attn/Concat_2 Concat
# /model/decoder/layers.30/encoder_attn/Reshape_1 Reshape
# /model/decoder/layers.30/encoder_attn/v_proj/MatMul MatMul
# /model/decoder/layers.30/encoder_attn/v_proj/Add Add
# /model/decoder/layers.30/encoder_attn/Reshape_2 Reshape
# /model/decoder/layers.30/encoder_attn/Transpose_1 Transpose
# /model/decoder/layers.30/encoder_attn/Transpose_2 Transpose
# /model/decoder/layers.30/encoder_attn/MatMul MatMul
# /model/decoder/layers.30/encoder_attn/Softmax Softmax
# /model/decoder/layers.30/encoder_attn/MatMul_1 MatMul
# /model/decoder/layers.30/encoder_attn/Transpose_3 Transpose
# Constant_6664 Constant
# /model/decoder/layers.30/encoder_attn/Unsqueeze_4 Unsqueeze
# Constant_6666 Constant
# /model/decoder/layers.30/encoder_attn/Unsqueeze_5 Unsqueeze
# /model/decoder/layers.30/encoder_attn/Constant_11 Constant
# /model/decoder/layers.30/encoder_attn/Concat_3 Concat
# /model/decoder/layers.30/encoder_attn/Reshape_3 Reshape
# /model/decoder/layers.30/encoder_attn/out_proj/MatMul MatMul
# /model/decoder/layers.30/encoder_attn/out_proj/Add Add
# /model/decoder/layers.30/Add_1 Add
# /model/decoder/layers.30/final_layer_norm/ReduceMean ReduceMean
# /model/decoder/layers.30/final_layer_norm/Sub Sub
# /model/decoder/layers.30/final_layer_norm/Constant Constant
# /model/decoder/layers.30/final_layer_norm/Pow Pow
# /model/decoder/layers.30/final_layer_norm/ReduceMean_1 ReduceMean
# /model/decoder/layers.30/final_layer_norm/Constant_1 Constant
# /model/decoder/layers.30/final_layer_norm/Add Add
# /model/decoder/layers.30/final_layer_norm/Sqrt Sqrt
# /model/decoder/layers.30/final_layer_norm/Div Div
# /model/decoder/layers.30/final_layer_norm/Mul Mul
# /model/decoder/layers.30/final_layer_norm/Add_1 Add
# /model/decoder/layers.30/fc1/MatMul MatMul
# /model/decoder/layers.30/fc1/Add Add
# /model/decoder/layers.30/activation_fn/Constant Constant
# /model/decoder/layers.30/activation_fn/Div Div
# /model/decoder/layers.30/activation_fn/Erf Erf
# /model/decoder/layers.30/activation_fn/Constant_1 Constant
# /model/decoder/layers.30/activation_fn/Add Add
# /model/decoder/layers.30/activation_fn/Mul Mul
# /model/decoder/layers.30/activation_fn/Constant_2 Constant
# /model/decoder/layers.30/activation_fn/Mul_1 Mul
# /model/decoder/layers.30/fc2/MatMul MatMul
# /model/decoder/layers.30/fc2/Add Add
# /model/decoder/layers.30/Add_2 Add
# /model/decoder/layers.31/self_attn_layer_norm/ReduceMean ReduceMean
# /model/decoder/layers.31/self_attn_layer_norm/Sub Sub
# /model/decoder/layers.31/self_attn_layer_norm/Constant Constant
# /model/decoder/layers.31/self_attn_layer_norm/Pow Pow
# /model/decoder/layers.31/self_attn_layer_norm/ReduceMean_1 ReduceMean
# /model/decoder/layers.31/self_attn_layer_norm/Constant_1 Constant
# /model/decoder/layers.31/self_attn_layer_norm/Add Add
# /model/decoder/layers.31/self_attn_layer_norm/Sqrt Sqrt
# /model/decoder/layers.31/self_attn_layer_norm/Div Div
# /model/decoder/layers.31/self_attn_layer_norm/Mul Mul
# /model/decoder/layers.31/self_attn_layer_norm/Add_1 Add
# /model/decoder/layers.31/self_attn/Shape Shape
# /model/decoder/layers.31/self_attn/Constant Constant
# /model/decoder/layers.31/self_attn/Gather Gather
# /model/decoder/layers.31/self_attn/Shape_1 Shape
# /model/decoder/layers.31/self_attn/Constant_1 Constant
# /model/decoder/layers.31/self_attn/Gather_1 Gather
# /model/decoder/layers.31/self_attn/q_proj/MatMul MatMul
# /model/decoder/layers.31/self_attn/q_proj/Add Add
# /model/decoder/layers.31/self_attn/Constant_2 Constant
# /model/decoder/layers.31/self_attn/Mul Mul
# Constant_6719 Constant
# /model/decoder/layers.31/self_attn/Unsqueeze Unsqueeze
# Constant_6721 Constant
# /model/decoder/layers.31/self_attn/Unsqueeze_1 Unsqueeze
# /model/decoder/layers.31/self_attn/Constant_3 Constant
# /model/decoder/layers.31/self_attn/Constant_4 Constant
# /model/decoder/layers.31/self_attn/Concat Concat
# /model/decoder/layers.31/self_attn/Reshape Reshape
# /model/decoder/layers.31/self_attn/Transpose Transpose
# /model/decoder/layers.31/self_attn/k_proj/MatMul MatMul
# Constant_6729 Constant
# /model/decoder/layers.31/self_attn/Unsqueeze_2 Unsqueeze
# /model/decoder/layers.31/self_attn/Constant_5 Constant
# /model/decoder/layers.31/self_attn/Constant_6 Constant
# /model/decoder/layers.31/self_attn/Constant_7 Constant
# /model/decoder/layers.31/self_attn/Concat_1 Concat
# Constant_6735 Constant
# /model/decoder/layers.31/self_attn/Unsqueeze_3 Unsqueeze
# /model/decoder/layers.31/self_attn/Constant_8 Constant
# /model/decoder/layers.31/self_attn/Constant_9 Constant
# /model/decoder/layers.31/self_attn/Constant_10 Constant
# /model/decoder/layers.31/self_attn/Concat_2 Concat
# /model/decoder/layers.31/self_attn/Reshape_1 Reshape
# /model/decoder/layers.31/self_attn/Transpose_1 Transpose
# /model/decoder/layers.31/self_attn/v_proj/MatMul MatMul
# /model/decoder/layers.31/self_attn/v_proj/Add Add
# /model/decoder/layers.31/self_attn/Reshape_2 Reshape
# /model/decoder/layers.31/self_attn/Transpose_2 Transpose
# /model/decoder/layers.31/self_attn/Transpose_3 Transpose
# /model/decoder/layers.31/self_attn/MatMul MatMul
# /model/decoder/layers.31/self_attn/Shape_2 Shape
# /model/decoder/layers.31/self_attn/Constant_11 Constant
# /model/decoder/layers.31/self_attn/Gather_2 Gather
# /model/decoder/layers.31/self_attn/Constant_12 Constant
# /model/decoder/layers.31/self_attn/Constant_13 Constant
# /model/decoder/layers.31/self_attn/Constant_14 Constant
# /model/decoder/layers.31/self_attn/Unsqueeze_4 Unsqueeze
# /model/decoder/layers.31/self_attn/Constant_15 Constant
# /model/decoder/layers.31/self_attn/Slice Slice
# /model/decoder/layers.31/self_attn/Add Add
# /model/decoder/layers.31/self_attn/Softmax Softmax
# /model/decoder/layers.31/self_attn/MatMul_1 MatMul
# /model/decoder/layers.31/self_attn/Transpose_4 Transpose
# Constant_6762 Constant
# /model/decoder/layers.31/self_attn/Unsqueeze_5 Unsqueeze
# Constant_6764 Constant
# /model/decoder/layers.31/self_attn/Unsqueeze_6 Unsqueeze
# /model/decoder/layers.31/self_attn/Constant_16 Constant
# /model/decoder/layers.31/self_attn/Concat_3 Concat
# /model/decoder/layers.31/self_attn/Reshape_3 Reshape
# /model/decoder/layers.31/self_attn/out_proj/MatMul MatMul
# /model/decoder/layers.31/self_attn/out_proj/Add Add
# /model/decoder/layers.31/Add Add
# /model/decoder/layers.31/encoder_attn_layer_norm/ReduceMean ReduceMean
# /model/decoder/layers.31/encoder_attn_layer_norm/Sub Sub
# /model/decoder/layers.31/encoder_attn_layer_norm/Constant Constant
# /model/decoder/layers.31/encoder_attn_layer_norm/Pow Pow
# /model/decoder/layers.31/encoder_attn_layer_norm/ReduceMean_1 ReduceMean
# /model/decoder/layers.31/encoder_attn_layer_norm/Constant_1 Constant
# /model/decoder/layers.31/encoder_attn_layer_norm/Add Add
# /model/decoder/layers.31/encoder_attn_layer_norm/Sqrt Sqrt
# /model/decoder/layers.31/encoder_attn_layer_norm/Div Div
# /model/decoder/layers.31/encoder_attn_layer_norm/Mul Mul
# /model/decoder/layers.31/encoder_attn_layer_norm/Add_1 Add
# /model/decoder/layers.31/encoder_attn/Shape Shape
# /model/decoder/layers.31/encoder_attn/Constant Constant
# /model/decoder/layers.31/encoder_attn/Gather Gather
# /model/decoder/layers.31/encoder_attn/Shape_1 Shape
# /model/decoder/layers.31/encoder_attn/Constant_1 Constant
# /model/decoder/layers.31/encoder_attn/Gather_1 Gather
# /model/decoder/layers.31/encoder_attn/q_proj/MatMul MatMul
# /model/decoder/layers.31/encoder_attn/q_proj/Add Add
# /model/decoder/layers.31/encoder_attn/Constant_2 Constant
# /model/decoder/layers.31/encoder_attn/Mul Mul
# Constant_6793 Constant
# /model/decoder/layers.31/encoder_attn/Unsqueeze Unsqueeze
# Constant_6795 Constant
# /model/decoder/layers.31/encoder_attn/Unsqueeze_1 Unsqueeze
# /model/decoder/layers.31/encoder_attn/Constant_3 Constant
# /model/decoder/layers.31/encoder_attn/Constant_4 Constant
# /model/decoder/layers.31/encoder_attn/Concat Concat
# /model/decoder/layers.31/encoder_attn/Reshape Reshape
# /model/decoder/layers.31/encoder_attn/Transpose Transpose
# /model/decoder/layers.31/encoder_attn/k_proj/MatMul MatMul
# Constant_6803 Constant
# /model/decoder/layers.31/encoder_attn/Unsqueeze_2 Unsqueeze
# /model/decoder/layers.31/encoder_attn/Constant_5 Constant
# /model/decoder/layers.31/encoder_attn/Constant_6 Constant
# /model/decoder/layers.31/encoder_attn/Constant_7 Constant
# /model/decoder/layers.31/encoder_attn/Concat_1 Concat
# Constant_6809 Constant
# /model/decoder/layers.31/encoder_attn/Unsqueeze_3 Unsqueeze
# /model/decoder/layers.31/encoder_attn/Constant_8 Constant
# /model/decoder/layers.31/encoder_attn/Constant_9 Constant
# /model/decoder/layers.31/encoder_attn/Constant_10 Constant
# /model/decoder/layers.31/encoder_attn/Concat_2 Concat
# /model/decoder/layers.31/encoder_attn/Reshape_1 Reshape
# /model/decoder/layers.31/encoder_attn/v_proj/MatMul MatMul
# /model/decoder/layers.31/encoder_attn/v_proj/Add Add
# /model/decoder/layers.31/encoder_attn/Reshape_2 Reshape
# /model/decoder/layers.31/encoder_attn/Transpose_1 Transpose
# /model/decoder/layers.31/encoder_attn/Transpose_2 Transpose
# /model/decoder/layers.31/encoder_attn/MatMul MatMul
# /model/decoder/layers.31/encoder_attn/Softmax Softmax
# /model/decoder/layers.31/encoder_attn/MatMul_1 MatMul
# /model/decoder/layers.31/encoder_attn/Transpose_3 Transpose
# Constant_6825 Constant
# /model/decoder/layers.31/encoder_attn/Unsqueeze_4 Unsqueeze
# Constant_6827 Constant
# /model/decoder/layers.31/encoder_attn/Unsqueeze_5 Unsqueeze
# /model/decoder/layers.31/encoder_attn/Constant_11 Constant
# /model/decoder/layers.31/encoder_attn/Concat_3 Concat
# /model/decoder/layers.31/encoder_attn/Reshape_3 Reshape
# /model/decoder/layers.31/encoder_attn/out_proj/MatMul MatMul
# /model/decoder/layers.31/encoder_attn/out_proj/Add Add
# /model/decoder/layers.31/Add_1 Add
# /model/decoder/layers.31/final_layer_norm/ReduceMean ReduceMean
# /model/decoder/layers.31/final_layer_norm/Sub Sub
# /model/decoder/layers.31/final_layer_norm/Constant Constant
# /model/decoder/layers.31/final_layer_norm/Pow Pow
# /model/decoder/layers.31/final_layer_norm/ReduceMean_1 ReduceMean
# /model/decoder/layers.31/final_layer_norm/Constant_1 Constant
# /model/decoder/layers.31/final_layer_norm/Add Add
# /model/decoder/layers.31/final_layer_norm/Sqrt Sqrt
# /model/decoder/layers.31/final_layer_norm/Div Div
# /model/decoder/layers.31/final_layer_norm/Mul Mul
# /model/decoder/layers.31/final_layer_norm/Add_1 Add
# /model/decoder/layers.31/fc1/MatMul MatMul
# /model/decoder/layers.31/fc1/Add Add
# /model/decoder/layers.31/activation_fn/Constant Constant
# /model/decoder/layers.31/activation_fn/Div Div
# /model/decoder/layers.31/activation_fn/Erf Erf
# /model/decoder/layers.31/activation_fn/Constant_1 Constant
# /model/decoder/layers.31/activation_fn/Add Add
# /model/decoder/layers.31/activation_fn/Mul Mul
# /model/decoder/layers.31/activation_fn/Constant_2 Constant
# /model/decoder/layers.31/activation_fn/Mul_1 Mul
# /model/decoder/layers.31/fc2/MatMul MatMul
# /model/decoder/layers.31/fc2/Add Add
# /model/decoder/layers.31/Add_2 Add
# /model/decoder/layer_norm/ReduceMean ReduceMean
# /model/decoder/layer_norm/Sub Sub
# /model/decoder/layer_norm/Constant Constant
# /model/decoder/layer_norm/Pow Pow
# /model/decoder/layer_norm/ReduceMean_1 ReduceMean
# /model/decoder/layer_norm/Constant_1 Constant
# /model/decoder/layer_norm/Add Add
# /model/decoder/layer_norm/Sqrt Sqrt
# /model/decoder/layer_norm/Div Div
# /model/decoder/layer_norm/Mul Mul
# /model/decoder/layer_norm/Add_1 Add
# Transpose_5242 Transpose
# /proj_out/MatMul MatMul

# %%
import onnx
from onnxruntime.quantization import quantize_dynamic, QuantType

def quantize_onnx_model_to_int8(input_onnx_model_path, output_quantized_model_path):
    """
    Quantize an ONNX model to INT8 precision using dynamic quantization.
    Args:
        input_onnx_model_path: Path to the original ONNX model
        output_quantized_model_path: Path to save the quantized model
    """
    print(f"Quantizing model to INT8: {input_onnx_model_path}")

    # Perform dynamic quantization to INT8
    quantize_dynamic(
        model_input=input_onnx_model_path,
        model_output=output_quantized_model_path,
        weight_type=QuantType.QInt8,  # Quantize weights to 8-bit integers
        per_channel=False,            # Use per-tensor quantization (more compatible)
        reduce_range=True,            # Improves accuracy for some hardware
        op_types_to_quantize=['MatMul', 'Conv', 'Gemm'],  # Operations to quantize
        nodes_to_exclude=['/conv1/Conv']
    )

    print(f"Quantized model saved to: {output_quantized_model_path}")

    # Verify model was quantized successfully
    model = onnx.load(output_quantized_model_path)
    onnx.checker.check_model(model)  # Will raise an exception if model is invalid
    print(f"Quantized model validated successfully.")

    return output_quantized_model_path

# Example usage for both encoder and decoder models:
encoder_model_path = "onnx/out/encoder_model.onnx"  # Specify encoder model file
decoder_model_path = "onnx/out/decoder_model.onnx"  # Specify decoder model file

output_encoder_model_path = "onnx/out/encoder_model_quantized.onnx"  # Quantized encoder model path
output_decoder_model_path = "onnx/out/decoder_model_quantized.onnx"  # Quantized decoder model path

# Quantizing encoder and decoder models
quantized_encoder_model = quantize_onnx_model_to_int8(encoder_model_path, output_encoder_model_path)
quantized_decoder_model = quantize_onnx_model_to_int8(decoder_model_path, output_decoder_model_path)

print(f"Quantized encoder model is saved at: {quantized_encoder_model}")
print(f"Quantized decoder model is saved at: {quantized_decoder_model}")
# Out:
# Quantizing model to INT8: onnx/out/encoder_model.onnx
# WARNING:root:Please consider to run pre-processing before quantization. Refer to example: https://github.com/microsoft/onnxruntime-inference-examples/blob/main/quantization/image_classification/cpu/ReadMe.md
# Quantized model saved to: onnx/out/encoder_model_quantized.onnx
# Quantized model validated successfully.
# Quantizing model to INT8: onnx/out/decoder_model.onnx
# WARNING:root:Please consider to run pre-processing before quantization. Refer to example: https://github.com/microsoft/onnxruntime-inference-examples/blob/main/quantization/image_classification/cpu/ReadMe.md
# Quantized model saved to: onnx/out/decoder_model_quantized.onnx
# Quantized model validated successfully.
# Quantized encoder model is saved at: onnx/out/encoder_model_quantized.onnx
# Quantized decoder model is saved at: onnx/out/decoder_model_quantized.onnx

# %% [markdown]
# ## Inference

# %%
import onnx
import onnxruntime as ort
import numpy as np
import librosa
from transformers import WhisperTokenizer
from datasets import load_dataset

# Load ONNX models
encoder_model_path = "onnx/out/encoder_model.onnx"  # Unquantized encoder model path
decoder_model_path = "onnx/out/decoder_model.onnx"  # Unquantized decoder model path

# Load the models into ONNX Runtime
encoder_session = ort.InferenceSession(encoder_model_path)
decoder_session = ort.InferenceSession(decoder_model_path)

# Load WhisperTokenizer for converting speech to token ids
tokenizer = WhisperTokenizer.from_pretrained("openai/whisper-large")

def preprocess_audio(audio_path, target_sr=16000, target_length=3000):
    """
    Preprocess the audio file to fit the input format expected by the Whisper model.
    Args:
        audio_path: Path to the audio file
        target_sr: Target sample rate for Whisper (default: 16000)
        target_length: Target length for the audio sequence (default: 3000)
    Returns:
        numpy array: Preprocessed audio
    """
    # Load the audio file
    audio, sr = librosa.load(audio_path, sr=None)
    
    # Resample to target sample rate
    if sr != target_sr:
        audio = librosa.resample(audio, orig_sr=sr, target_sr=target_sr)
    
    # Normalize audio to range [-1, 1]
    audio = audio / np.max(np.abs(audio))

    # Ensure the audio length matches the model's expected length
    if len(audio) < target_length:
        # If the audio is shorter, pad with zeros
        audio = np.pad(audio, (0, target_length - len(audio)))
    else:
        # If the audio is longer, truncate it
        audio = audio[:target_length]

    return audio

def encode_audio(audio, encoder_session):
    """
    Encode the audio using the encoder model.
    Args:
        audio: Preprocessed audio
        encoder_session: ONNX Runtime session for the encoder model
    Returns:
        numpy array: Encoder output (feature embeddings)
    """
    # Prepare audio input (reshape as required by the model)
    input_audio = np.expand_dims(audio, axis=0)  # Add batch dimension
    input_audio = np.expand_dims(input_audio, axis=0)  # Add channel dimension
    
    # Run inference on the encoder
    encoder_input_name = encoder_session.get_inputs()[0].name
    encoder_output_name = encoder_session.get_outputs()[0].name
    encoder_output = encoder_session.run([encoder_output_name], {encoder_input_name: input_audio})
    
    return encoder_output[0]

def decode_output(encoder_output, decoder_session):
    """
    Decode the encoded features using the decoder model to get the transcription.
    Args:
        encoder_output: Output from the encoder model
        decoder_session: ONNX Runtime session for the decoder model
    Returns:
        str: Transcription or translated text
    """
    # Convert encoder output to float32 (if it's not already)
    encoder_hidden_states = encoder_output.astype(np.float32)

    # Tokenize the encoder output (this assumes you have a tokenizer available)
    token_ids = tokenizer.encode("decoded text from encoder", return_tensors="np").input_ids  # Example tokenization
    
    # Get decoder input names and output names
    decoder_input_name = decoder_session.get_inputs()[0].name
    decoder_hidden_state_name = decoder_session.get_inputs()[1].name  # This may vary depending on your model
    decoder_output_name = decoder_session.get_outputs()[0].name

    # Run inference on the decoder, passing token_ids (int64) and hidden states (float32)
    decoder_output = decoder_session.run([decoder_output_name], {
        decoder_input_name: token_ids,  # Token IDs (int64)
        decoder_hidden_state_name: encoder_hidden_states  # Hidden states (float32)
    })
    
    # Post-process decoder output (e.g., convert logits to tokens)
    transcription = np.argmax(decoder_output[0], axis=-1)  # Assuming logits
    
    return transcription

def audio_to_text(audio_path):
    """
    Complete flow for converting audio to text using Whisper (encoder + decoder).
    Args:
        audio_path: Path to the input audio file
    Returns:
        str: Transcription or translated text
    """
    # Step 1: Preprocess the audio
    audio = preprocess_audio(audio_path)
    
    # Step 2: Encode the audio using the encoder model
    encoder_output = encode_audio(audio, encoder_session)
    
    # Step 3: Decode the encoder output to get the transcription
    transcription = decode_output(encoder_output, decoder_session)
    
    return transcription

# Example usage:
#audio_path = "carlin_who_gives_x.wav"
dataset = load_dataset("distil-whisper/librispeech_long", "clean", split="validation")
sample = dataset[0]["audio"]
transcription = audio_to_text(sample)
print("Transcription:", transcription)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 123
#     121 dataset = load_dataset("distil-whisper/librispeech_long", "clean", split="validation")
#     122 sample = dataset[0]["audio"]
# --> 123 transcription = audio_to_text(sample)
#     124 print("Transcription:", transcription)
#
# Cell In[1], line 109, in audio_to_text(audio_path)
#     101 """
#     102 Complete flow for converting audio to text using Whisper (encoder + decoder).
#     103 Args:
#    (...)    106     str: Transcription or translated text
#     107 """
#     108 # Step 1: Preprocess the audio
# --> 109 audio = preprocess_audio(audio_path)
#     111 # Step 2: Encode the audio using the encoder model
#     112 encoder_output = encode_audio(audio, encoder_session)
#
# Cell In[1], line 30, in preprocess_audio(audio_path, target_sr, target_length)
#      20 """
#      21 Preprocess the audio file to fit the input format expected by the Whisper model.
#      22 Args:
#    (...)     27     numpy array: Preprocessed audio
#      28 """
#      29 # Load the audio file
# ---> 30 audio, sr = librosa.load(audio_path, sr=None)
#      32 # Resample to target sample rate
#      33 if sr != target_sr:
#
# File c:\Users\joel\Desktop\AI-ML-Engineering-MonoRepo\.venv\Lib\site-packages\librosa\util\decorators.py:88, in deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      86 extra_args = len(args) - len(all_args)
#      87 if extra_args <= 0:
# ---> 88     return f(*args, **kwargs)
#      90 # extra_args > 0
#      91 args_msg = [
#      92     "{}={}".format(name, arg)
#      93     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      94 ]
#
# File c:\Users\joel\Desktop\AI-ML-Engineering-MonoRepo\.venv\Lib\site-packages\librosa\core\audio.py:164, in load(path, sr, mono, offset, duration, dtype, res_type)
#     161 else:
#     162     # Otherwise try soundfile first, and then fall back if necessary
#     163     try:
# --> 164         y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     166     except RuntimeError as exc:
#     167         # If soundfile failed, try audioread instead
#     168         if isinstance(path, (str, pathlib.PurePath)):
#
# File c:\Users\joel\Desktop\AI-ML-Engineering-MonoRepo\.venv\Lib\site-packages\librosa\core\audio.py:195, in __soundfile_load(path, offset, duration, dtype)
#     192     context = path
#     193 else:
#     194     # Otherwise, create the soundfile object
# --> 195     context = sf.SoundFile(path)
#     197 with context as sf_desc:
#     198     sr_native = sf_desc.samplerate
#
# File c:\Users\joel\Desktop\AI-ML-Engineering-MonoRepo\.venv\Lib\site-packages\soundfile.py:690, in SoundFile.__init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd, compression_level, bitrate_mode)
#     687 self._bitrate_mode = bitrate_mode
#     688 self._info = _create_info_struct(file, mode, samplerate, channels,
#     689                                  format, subtype, endian)
# --> 690 self._file = self._open(file, mode_int, closefd)
#     691 if set(mode).issuperset('r+') and self.seekable():
#     692     # Move write position to 0 (like in Python file objects)
#     693     self.seek(0)
#
# File c:\Users\joel\Desktop\AI-ML-Engineering-MonoRepo\.venv\Lib\site-packages\soundfile.py:1261, in SoundFile._open(self, file, mode_int, closefd)
#    1258     file_ptr = _snd.sf_open_virtual(self._init_virtual_io(file),
#    1259                                     mode_int, self._info, _ffi.NULL)
#    1260 else:
# -> 1261     raise TypeError("Invalid file: {0!r}".format(self.name))
#    1262 if file_ptr == _ffi.NULL:
#    1263     # get the actual error code
#    1264     err = _snd.sf_error(file_ptr)
#
# TypeError: Invalid file: {'path': '0d38672e0bbdbdc460af55b8bb84a15b2730db2819f2af64f9c777d4d586f2de', 'array': array([0.00238037, 0.0020752 , 0.00198364, ..., 0.00024414, 0.00048828,
#        0.0005188 ]), 'sampling_rate': 16000}

# %%
# Ensure you're using a compatible version of ONNX Runtime
print(f"ONNX Runtime Version: {ort.__version__}")
# Out:
# ONNX Runtime Version: 1.21.0
